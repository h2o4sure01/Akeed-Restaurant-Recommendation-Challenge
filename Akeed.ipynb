# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order = pd.read_csv('orders.csv')
vendor = pd.read_csv('vendors.csv')
train_loc = pd.read_csv('train_locations.csv')
test_loc = pd.read_csv('test_locations.csv')
train_cust = pd.read_csv('train_customers.csv')
test_cust = pd.read_csv('test_customers.csv')
submission = pd.read_csv('SampleSubmission.csv')
# Out:
# /home/korede/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (15,16,18,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Printing out the datas

# %%
train_loc.head(3)
# Out:
#   customer_id  location_number location_type  latitude  longitude
# 0     02SFNJH                0           NaN  1.682392 -78.789737
# 1     02SFNJH                1           NaN  1.679137   0.766823
# 2     02SFNJH                2           NaN -0.498648   0.661241

# %%
train_cust.head(3)
# Out:
#   akeed_customer_id gender  dob  status  verified language  \
# 0           TCHWPBT   Male  NaN       1         1       EN
# 1           ZGFSYCZ   Male  NaN       1         1       EN
# 2           S2ALZFL   Male  NaN       0         1       EN
#
#             created_at           updated_at
# 0  2018-02-07 19:16:23  2018-02-07 19:16:23
# 1  2018-02-09 12:04:42  2018-02-09 12:04:41
# 2  2018-03-14 18:31:43  2018-03-14 18:31:42

# %%
order.tail(3)
# Out:
#         akeed_order_id customer_id  item_count  grand_total  payment_mode  \
# 135300        415510.0     LYTAAV0         4.0         18.2             2
# 135301        415512.0     NEV9A5D         3.0          7.7             1
# 135302        415515.0     77KCRC1         1.0          6.8             2
#
#        promo_code  vendor_discount_amount  promo_code_discount_percentage  \
# 135300        NaN                     0.0                             0.0
# 135301  NUE5BZAA7                     0.0                             0.0
# 135302        NaN                     0.0                             0.0
#
#        is_favorite is_rated  ...  driver_accepted_time  ready_for_pickup_time  \
# 135300          No       No  ...   2020-03-01 00:04:28    2020-03-01 00:10:34
# 135301          No       No  ...   2020-03-01 00:06:14    2020-03-01 00:08:10
# 135302          No       No  ...   2020-03-01 00:07:21    2020-03-01 00:14:12
#
# ...

# %%
vendor.head(3)
# Out:
#    id  authentication_id  latitude  longitude vendor_category_en  \
# 0   4           118597.0 -0.588596   0.754434        Restaurants
# 1  13           118608.0 -0.471654   0.744470        Restaurants
# 2  20           118616.0 -0.407527   0.643681        Restaurants
#
#    vendor_category_id  delivery_charge  serving_distance  is_open  \
# 0                 2.0              0.0               6.0      1.0
# 1                 2.0              0.7               5.0      1.0
# 2                 2.0              0.0               8.0      1.0
#
#        OpeningTime  ... open_close_flags                 vendor_tag  \
# 0  11:00AM-11:30PM  ...              1.0  2,4,5,8,91,22,12,24,16,23
# 1  08:30AM-10:30PM  ...              1.0  4,41,51,34,27,15,24,16,28
# 2  08:00AM-10:45PM  ...              1.0                  4,8,91,10
#
#                                      vendor_tag_name one_click_vendor  \
# 0  Arabic,Breakfast,Burgers,Desserts,Free Deliver...                Y
# ...

# %%
print(order.shape, train_loc.shape, test_loc.shape, train_cust.shape, test_cust.shape)
# Out:
# (135303, 26) (59503, 5) (16720, 5) (34674, 8) (9768, 8)

# %%
vendor['CID X LOC_NUM X VENDOR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CID X LOC_NUM X VENDOR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-6d41b2cc980c> in <module>
# ...
